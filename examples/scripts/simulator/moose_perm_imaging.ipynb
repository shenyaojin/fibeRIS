# %% [markdown]
# # Example: fiberis' permeability imaging full pipeline test
#
# Shenyao Jin, shenyaojin@mines.edu
#
# `fiberis` has a full pipeline for permeability imaging, which is a process that takes raw RFS-DSS data as input and produces permeability images as output.
#
# For this script, I'm going to show how `fiberis` can build a forward-modeling example.
